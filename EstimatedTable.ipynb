# %%
import pandas as pd

Budget = 3000 # 總預算 (限定整數, 每1000+)
LoopBudget = 500 # 每組迴圈預算
Commission = 40 # 設定傭金的金額
InitialAccountBudget = 1000 # 初始帳戶的基本資金
AverageLotsPerLoop = 0.25 # 每組迴圈平均手數/周數
SubAccountNumbers = 5 # 子帳號數目
WeeklyNumbers = 104 # 左側總計週數
WeeklyLots = 0 # 每週手數
# AccumulationLots = 0  # 累積手數
AutoAddLoop = True # 複利 or 單利


titlearr = ['週數', '每週總手數', '累積手數','新增迴圈數', '累積500美金加開一迴圈']

for i in range(1, SubAccountNumbers + 1):
    titlearr.insert(0 + i, '帳戶{index}'.format(index = i))

print(titlearr)
# Out:
# ['週數', '帳戶1', '帳戶2', '帳戶3', '帳戶4', '帳戶5', '每週總手數', '累積手數', '新增迴圈數', '累積500美金加開一迴圈']

# %%
dataList = []
def EstimatedTable(WeeklyNumbers, LoopBudget, AverageLotsPerLoop, SubAccountNumbers, AutoAddLoop):
    # 週數
    AccountList = []
    AccumulationLots = 0 # 累積手數
    for week in range(1, WeeklyNumbers + 1):
        data = {}
        data['週數'] = week
        data['每週總手數'] = 0
        data['累積手數'] = 0
        
        # 初始資金及手數配置
        if data['週數'] == 1 :
            OriginalAccountNumbers = int(Budget / InitialAccountBudget)
            for i in range(1, OriginalAccountNumbers + 1):
                data['帳戶{}總資金'.format(i)] = InitialAccountBudget
                data['帳戶{}手數'.format(i)] = data['帳戶{}總資金'.format(i)]/LoopBudget*AverageLotsPerLoop
            
            for i in range(OriginalAccountNumbers + 1, SubAccountNumbers + 1):
                data['帳戶{}總資金'.format(i)] = 0
                data['帳戶{}手數'.format(i)] = data['帳戶{}總資金'.format(i)]/LoopBudget*AverageLotsPerLoop

            # 每週總手數
            for i in range(1, SubAccountNumbers + 1):
                data['每週總手數'] = data['每週總手數'] + data['帳戶{}手數'.format(i)]
            
            # 累積手數
            AccumulationLots = data['每週總手數']
            data['累積手數'] = AccumulationLots
        else:
            OriginalAccountNumbers = int(Budget / InitialAccountBudget)
            for i in range(1, OriginalAccountNumbers + 1):
                data['帳戶{}總資金'.format(i)] = InitialAccountBudget
                data['帳戶{}手數'.format(i)] = data['帳戶{}總資金'.format(i)]/LoopBudget*AverageLotsPerLoop
            for i in range(OriginalAccountNumbers + 1, SubAccountNumbers + 1):
                data['帳戶{}總資金'.format(i)] = 0
                data['帳戶{}手數'.format(i)] = data['帳戶{}總資金'.format(i)]/LoopBudget*AverageLotsPerLoop
                
            # 每週總手數
            for i in range(1, SubAccountNumbers + 1):
                data['每週總手數'] = data['每週總手數'] + data['帳戶{}手數'.format(i)]

            # 累積手數
            AccumulationLots = AccumulationLots + data['每週總手數']
            data['累積手數'] = AccumulationLots

        dataList.append(data)
        pass
    print(dataList)
EstimatedTable(WeeklyNumbers, LoopBudget, AverageLotsPerLoop, SubAccountNumbers, AutoAddLoop)
# Out:
# [{'週數': 1, '每週總手數': 1.5, '累積手數': 1.5, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 2, '每週總手數': 1.5, '累積手數': 3.0, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 3, '每週總手數': 1.5, '累積手數': 4.5, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 4, '每週總手數': 1.5, '累積手數': 6.0, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 5, '每週總手數': 1.5, '累積手數': 7.5, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 6, '每週總手數': 1.5, '累積手數': 9.0, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 7, '每週總手數': 1.5, '累積手數': 10.5, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 8, '每週總手數': 1.5, '累積手數': 12.0, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 9, '每週總手數': 1.5, '累積手數': 13.5, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 10, '每週總手數': 1.5, '累積手數': 15.0, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 11, '每週總手數': 1.5, '累積手數': 16.5, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 12, '每週總手數': 1.5, '累積手數': 18.0, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 13, '每週總手數': 1.5, '累積手數': 19.5, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 14, '每週總手數': 1.5, '累積手數': 21.0, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 15, '每週總手數': 1.5, '累積手數': 22.5, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 16, '每週總手數': 1.5, '累積手數': 24.0, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 17, '每週總手數': 1.5, '累積手數': 25.5, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 18, '每週總手數': 1.5, '累積手數': 27.0, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 19, '每週總手數': 1.5, '累積手數': 28.5, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 20, '每週總手數': 1.5, '累積手數': 30.0, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 21, '每週總手數': 1.5, '累積手數': 31.5, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': 0.0, '帳戶5總資金': 0, '帳戶5手數': 0.0}, {'週數': 22, '每週總手數': 1.5, '累積手數': 33.0, '帳戶1總資金': 1000, '帳戶1手數': 0.5, '帳戶2總資金': 1000, '帳戶2手數': 0.5, '帳戶3總資金': 1000, '帳戶3手數': 0.5, '帳戶4總資金': 0, '帳戶4手數': ...
